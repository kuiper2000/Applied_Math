# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def poisson_kernel(r, theta):
    return 1 / (2 * np.pi) * (1 - r**2) / (1 + r**2 - 2 * r * np.cos(theta))

r = np.linspace(0, 1, 100)
theta = np.linspace(0, 2 * np.pi, 100)
R, Theta = np.meshgrid(r, theta)
Z = poisson_kernel(R, Theta)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(R * np.cos(Theta), R * np.sin(Theta), Z, cmap='viridis')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('Poisson Kernel')

plt.show()
# Out:
# /var/folders/x1/nb2x5h5j08b2xx8xkc64r43m0000gn/T/ipykernel_22788/3355273622.py:6: RuntimeWarning: invalid value encountered in divide
#   return 1 / (2 * np.pi) * (1 - r**2) / (1 + r**2 - 2 * r * np.cos(theta))
